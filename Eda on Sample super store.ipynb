# %% [markdown]
# # Task5 : Exploratory Data Analysis On `Sample Superstore`

# %% [markdown]
# There are several options for getting the dataset into Jupyter:
#
# Download the CSV manually and upload it via Jupyter's GUI

# %% [markdown]
# Importing libraries using ``import`` `as` function

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Importing The Data file

# %%
sample_df = pd.read_csv('Sample_Store.csv')

# %%
sample_df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ### Select Top 10 samples

# %%
sample_df.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %% [markdown]
# ### Describe

# %%
sample_df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### Finding The Numbers Of Uniques Values in Each Coloumn

# %%
sample_df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
sample_df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Check The Type of samples using `.info()`

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Postal Code   9977 non-null   int64
#  6   Region        9977 non-null   object
#  7   Category      9977 non-null   object
#  8   Sub-Category  9977 non-null   object
#  9   Sales         9977 non-null   float64
#  10  Quantity      9977 non-null   int64
#  11  Discount      9977 non-null   float64
#  12  Profit        9977 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Shape (Raw,Coloumn)

# %%
sample_df.shape
# Out:
# (9977, 13)

# %%
sample_df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %% [markdown]
# ### Checking If The Data Contains Any Null Value

# %%
sample_df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# # Ploting Graphs

# %%
Sale = sample_df['Sales']

# %%
Sale;

# %%
Profi = sample_df['Profit']

# %%
Profi
# Out:
# 0        41.9136
# 1       219.5820
# 2         6.8714
# 3      -383.0310
# 4         2.5164
#           ...
# 9989      4.1028
# 9990     15.6332
# 9991     19.3932
# 9992     13.3200
# 9993     72.9480
# Name: Profit, Length: 9977, dtype: float64

# %% [markdown]
# ### Sales Vs profit

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(12,6))
plt.xticks(rotation=75)
plt.plot(Profi)
plt.title('Total Profit')
plt.xlabel('Number of sales')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# Here we can observe that the rise and fall are varies

# %%
correla = sample_df.corr()
plt.figure(figsize=(15,8))
sns.heatmap(correla,annot = True )
plt.show()

# %% [markdown]
# ### Most Used Ship Mode

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=75)
sns.countplot(sample_df['Ship Mode'])
plt.title('Highely Used Ship Mode')
plt.xlabel('Types of Ship Mode')
plt.ylabel('No Of Sales')
plt.show()

# %% [markdown]
# ### We can observe that the `standard class` is the most used ship mode type

# %% [markdown]
# ### Heighest Sales Placed by a State

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=75)
sns.countplot(sample_df['State'])
plt.title('Highest order placed by a state')
plt.xlabel('States')
plt.ylabel('No Of Orders')
plt.show()

# %% [markdown]
# ### The sales are varies in every states here we can see the `california` is the heighest demanding states of america

# %% [markdown]
# ### Heighest Sales Placed by a Region

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=75)
sns.countplot(sample_df['Region'])
plt.title('Highest No Of order placed by region')
plt.xlabel('Region')
plt.ylabel('No Of Orders')
plt.show()

# %% [markdown]
# ### Here we can Observe that the `west` part of united states of america is the heighest demanding part

# %% [markdown]
# ## Most Orderd Category

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=75)
sns.countplot(sample_df['Category'])
plt.title('Mostly orderd Categories ')
plt.xlabel('Types of Categories')
plt.ylabel('No Of Orders')
plt.show()

# %% [markdown]
# ### We can obeserve that the `office supplies` are highely demanding categorys

# %% [markdown]
# ## Mostly orderd sub Categories

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation=75)
sns.countplot(sample_df['Sub-Category'])
plt.title('Mostly orderd sub Categories ')
plt.xlabel('Types of sub Categories')
plt.ylabel('No Of Orders')
plt.show()

# %% [markdown]
# ### Here we can observe that the `Bindera` is one of the highely demanding sub categorys.

# %% [markdown]
# # Top 5 Sales

# %%
Top_Sales = sample_df.sort_values('Sales',ascending=False ).head()

# %%
Top_Sales
# Out:
#            Ship Mode      Segment        Country           City       State  \
# 2697  Standard Class  Home Office  United States   Jacksonville     Florida
# 6826  Standard Class    Corporate  United States      Lafayette     Indiana
# 8153     First Class     Consumer  United States        Seattle  Washington
# 2623     First Class  Home Office  United States  New York City    New York
# 4190  Standard Class     Consumer  United States         Newark    Delaware
#
#       Postal Code   Region    Category Sub-Category      Sales  Quantity  \
# 2697        32216    South  Technology     Machines  22638.480         6
# 6826        47905  Central  Technology      Copiers  17499.950         5
# 8153        98115     West  Technology      Copiers  13999.960         4
# 2623        10024     East  Technology      Copiers  11199.968         4
# 4190        19711     East  Technology      Copiers  10499.970         3
#
#       Discount     Profit
# 2697       0.5 -1811.0784
# ...

# %% [markdown]
# Here we observe that the heighest sales

# %% [markdown]
# ## Top 5 Demanding City

# %%
plt.figure(figsize=(15,6))
plt.bar(Top_Sales['City'],Top_Sales['Sales'],color='green')
plt.title('Top 5 orderd city ')
plt.xlabel('City')
plt.ylabel('Sales');

# %% [markdown]
# ### we observe that the above 5 citys are placing most no of orders anong the other citys

# %% [markdown]
# # Last 5 Sales

# %%
Last_sales = sample_df.sort_values('Sales',ascending=False ).tail()

# %%
Last_sales
# Out:
#            Ship Mode    Segment        Country          City         State  \
# 2106        Same Day  Corporate  United States      Mesquite         Texas
# 4711        Same Day   Consumer  United States  Philadelphia  Pennsylvania
# 8658  Standard Class  Corporate  United States       Chicago      Illinois
# 9292        Same Day  Corporate  United States          Waco         Texas
# 4101  Standard Class   Consumer  United States       Houston         Texas
#
#       Postal Code   Region         Category Sub-Category  Sales  Quantity  \
# 2106        75150  Central  Office Supplies      Binders  0.876         1
# 4711        19120     East  Office Supplies      Binders  0.852         1
# 8658        60623  Central  Office Supplies      Binders  0.836         1
# 9292        76706  Central  Office Supplies      Binders  0.556         1
# 4101        77095  Central  Office Supplies   Appliances  0.444         1
#
#       Discount  Profit
# 2106       0.8 -1.4016
# ...

# %% [markdown]
# ## Least Demanding citys

# %%
plt.figure(figsize=(15,6))
plt.bar(Last_sales['City'],Last_sales['Sales'],color='green')
plt.title('Last 5 orderd city')
plt.xlabel('City')
plt.ylabel('Sales');

# %% [markdown]
# ### we observe that the above 5 citys are placing least no of orders anong the other citys

# %% [markdown]
# # Groupby method

# %% [markdown]
# (1) Iterating through Groups. With the groupby object in hand, we can iterate through the object similar.
# Select a Group.
#
# (2) View Groups.
#
# (3) Using the get_group () method, we can select a single group.

# %%
Total =sample_df.groupby('Sub-Category')['Quantity'].sum().reset_index()

# %%
Total
# Out:
#    Sub-Category  Quantity
# 0   Accessories      2976
# 1    Appliances      1729
# 2           Art      2996
# 3       Binders      5971
# 4     Bookcases       868
# 5        Chairs      2351
# 6       Copiers       234
# 7     Envelopes       906
# 8     Fasteners       914
# 9   Furnishings      3560
# 10       Labels      1396
# 11     Machines       440
# 12        Paper      5144
# 13       Phones      3289
# 14      Storage      3158
# 15     Supplies       647
# 16       Tables      1241

# %% [markdown]
# Here we are agregating the sub categorys and quantity by using groupby method

# %% [markdown]
# # Heighest saleing Sub-categorys

# %%
plt.figure(figsize=(15,10))
plt.title('Heighest saleing Sub-categorys')
sns.set_style('darkgrid')
sns.barplot(sample_df['Region'],sample_df['Sales'],hue=sample_df['Sub-Category']);

# %% [markdown]
# ## Heighest Saleing Category Per Region

# %%
plt.figure(figsize=(15,10))
plt.title('Region With Heighest Sales')
sns.set_style('darkgrid')
sns.barplot(sample_df['Region'],sample_df['Sales'],hue=sample_df['Category']);

# %% [markdown]
# ### Here we observe that the `Technology` is the heighest Demanding categorys among all the categorys

# %% [markdown]
# ## Heighest Saleing Sub-Category Top 5 States

# %%
plt.figure(figsize=(15,8))
plt.title('Heighest saled Sub-category')
sns.set_style('darkgrid')
sns.barplot(Top_Sales['State'],Top_Sales['Sales'],hue=Top_Sales['Sub-Category']);

# %% [markdown]
# ### Here we observe that the showing states are heighley demanding with specifi categorys `Machiens`,`copiers`

# %% [markdown]
# ## Lowest Saleing sub-Category Top 3 States

# %%
plt.figure(figsize=(15,8))
plt.title('Lowest saled Sub-category')
sns.set_style('darkgrid')
sns.barplot(Last_sales['State'],Last_sales['Sales'],hue=Last_sales['Sub-Category']);

# %% [markdown]
# ### Here we see that the least demanding states with their demanding categorys

# %% [markdown]
# ## Heighly Profitable sub Category

# %%
plt.figure(figsize=(15,8))
plt.title('Heighest saled Sub-category')
sns.set_style('darkgrid')
sns.barplot(Top_Sales['City'],Top_Sales['Sales'],hue=Top_Sales['Profit']);

# %% [markdown]
# ### Here we observe the given showing citys are geving the heighest no of profits

# %% [markdown]
# ## Lower Profitable sub Categorys

# %%
plt.figure(figsize=(10,8))
plt.title('Lowest saled Sub-category')
sns.set_style('darkgrid')
sns.barplot(Last_sales['City'],Last_sales['Sales'],hue=Last_sales['Profit']);

# %% [markdown]
# ### Here are some low profitable categories which orderd by given citys

# %% [markdown]
# ##  Discount per Sub-Categorys

# %%
s=sample_df.sample(10)
s;

# %%
plt.figure(figsize=(15,8))
plt.title('Discount per Sub-Categorys')
sns.set_style('darkgrid')
sns.barplot(s['Sub-Category'],s['Sales'],hue=s['Discount']);

# %% [markdown]
# ### Here we observe that the among the all sub categorys `Machine` sub categorys are giving the heigher no of discount eventhough it is not heighely demanding

# %%
plt.figure(figsize=(15,8))
plt.title('Discount per Categorys')
sns.set_style('darkgrid')
sns.barplot(s['Category'],s['Sales'],hue=s['Discount']);

# %% [markdown]
# ### Here we observe that the `Technology` Categorys are giving heigher no of discount

# %% [markdown]
# # Heighest sealing Products

# %%
Sub_category = sample_df.groupby('Sub-Category')['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False).head(10)

# %%
Sub_category
# Out:
#    Sub-Category        Sales
# 13       Phones  330007.0540
# 5        Chairs  327777.7610
# 14      Storage  223843.6080
# 16       Tables  206965.5320
# 3       Binders  203409.1690
# 11     Machines  189238.6310
# 0   Accessories  167380.3180
# 6       Copiers  149528.0300
# 4     Bookcases  114879.9963
# 1    Appliances  107532.1610

# %%
plt.figure(figsize=(10,6))
plt.title('Top 10 Heighest sealing products')
plt.ylabel('Sales')
plt.xlabel('Products')
plt.bar(Sub_category['Sub-Category'],Sub_category['Sales']);

# %% [markdown]
# ### Here we can observe that the `phones` and `chairs` are one of the heighest sealing products

# %% [markdown]
# # Most Profitable Products

# %%
Heighest_profit=sample_df.groupby('Sub-Category')['Profit'].sum().reset_index().sort_values(by='Profit',ascending=False).head(10)

# %%
Heighest_profit
# Out:
#    Sub-Category      Profit
# 6       Copiers  55617.8249
# 13       Phones  44515.7306
# 0   Accessories  41936.6357
# 12        Paper  33944.2395
# 3       Binders  30228.0003
# 5        Chairs  26567.1278
# 14      Storage  21278.8264
# 1    Appliances  18138.0054
# 9   Furnishings  13052.7230
# 7     Envelopes   6964.1767

# %%
plt.figure(figsize=(10,6))
plt.title('Top 10 Heighest sealing products')
plt.ylabel('Sales')
plt.xlabel('Products')
plt.bar(Heighest_profit['Sub-Category'],Heighest_profit['Profit']);

# %% [markdown]
# ### Here we observe the top 10 heighley profitable products.

# %% [markdown]
# # Inferences and Conclusion

# %% [markdown]
# ### The data which i perform contains a immense possibilities To improve our analytics. By solving problems Build more confidence to perform better. The ways in which questions can be asked varies, so does the way of tackling a problem. Only the one that has been minutely observed and tested will provide results worth trusting.

# %% [markdown]
# ### The various types of graphs are used here to show the data in better way. The plots which have been built in this project can be used in Various Analysis.

# %% [markdown]
# # By Dhirendra Pathak

# %% [markdown]
# # Thanks To `The Spark Foundation` For Giving Me Theis Opertunity
